# %%
import numpy as np
import pandas as pd

# %%
d = {"Name" : ["A" , "B" , "C" , "D"] , "id" : [123,234,345,456]}
df = pd.DataFrame(d)
df
# Out:
#   Name   id
# 0    A  123
# 1    B  234
# 2    C  345
# 3    D  456

# %%
try:
    df.set_index('id' , inplace=True)
except Exception as e:
    print("Error:", e)
# Out:
# Error: "None of ['id'] are in the columns"

# %%
df
# Out:
#     Name
# id
# 123    A
# 234    B
# 345    C
# 456    D

# %%
df.reset_index()
# Out:
#     id Name
# 0  123    A
# 1  234    B
# 2  345    C
# 3  456    D

# %%
# pd.read_csv(r"C:\Users\AMIT\Documents\2 Data Science Preparation 30h\data science pre\DS G 51\AB_NYC_2019.csv")
df = pd.read_csv("CarPrice_Assignment.csv")

# %%
df.head(3)   # 5 rows
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# 0       3.47    2.68               9.0        111    5000       21         27
# 1       3.47    2.68               9.0        111    5000       21         27
# 2       2.68    3.47               9.0        154    5000       19         26
#
#      price  highwaympg.1
# 0  13495.0            27
# ...

# %%
df.tail(3) # 5 rows
# Out:
#      car_ID  symboling      CarName fueltype aspiration doornumber carbody  \
# 208     203         -1  volvo 244dl      gas        std       four   sedan
# 209     204         -1    volvo 246   diesel      turbo       four   sedan
# 210     205         -1  volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  ...  fuelsystem  boreratio  stroke  \
# 208        rwd          front      109.1  ...        mpfi       3.58    2.87
# 209        rwd          front      109.1  ...         idi       3.01    3.40
# 210        rwd          front      109.1  ...        mpfi       3.78    3.15
#
#      compressionratio horsepower peakrpm  citympg highwaympg    price  \
# 208               8.8        134    5500       18         23  21485.0
# 209              23.0        106    4800       26         27  22470.0
# 210               9.5        114    5400       19         25  22625.0
#
#      highwaympg.1
# 208            23
# 209            27
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=211, step=1)

# %%
df.shape
# Out:
# (211, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            211 non-null    int64
#  1   symboling         211 non-null    int64
#  2   CarName           211 non-null    object
#  3   fueltype          211 non-null    object
#  4   aspiration        211 non-null    object
#  5   doornumber        211 non-null    object
#  6   carbody           211 non-null    object
#  7   drivewheel        211 non-null    object
#  8   enginelocation    211 non-null    object
#  9   wheelbase         211 non-null    float64
#  10  carlength         211 non-null    float64
#  11  carwidth          211 non-null    float64
#  12  carheight         211 non-null    float64
#  13  curbweight        211 non-null    int64
#  14  enginetype        211 non-null    object
#  15  cylindernumber    211 non-null    object
# ...

# %%
col_number = df.select_dtypes("number").columns
col_number
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
col_object = df.select_dtypes("object").columns
col_object
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
# df[col_number]
df[col_object].head()
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3        alfa-romero giulia      gas        std        two  convertible
# 4       alfa-romero stelvio      gas        std        two  convertible
#
#   drivewheel enginelocation enginetype cylindernumber fuelsystem
# 0        rwd          front       dohc           four       mpfi
# 1        rwd          front       dohc           four       mpfi
# 2        rwd          front       ohcv            six       mpfi
# 3        rwd          front       dohc           four       mpfi
# 4        rwd          front       dohc           four       mpfi

# %%
df[col_number].describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            211.0    100.127962    60.842480     1.00    47.50
# symboling         211.0      0.876777     1.262643    -2.00     0.00
# wheelbase         211.0     98.523697     6.108083    86.60    94.50
# carlength         211.0    173.922749    12.183840   141.10   166.80
# carwidth          211.0     65.869668     2.129035    60.30    64.10
# carheight         211.0     53.618957     2.503525    47.80    51.80
# curbweight        211.0   2557.957346   513.846700  1488.00  2179.50
# enginesize        211.0    127.203791    41.117615    61.00    98.00
# boreratio         211.0      3.326256     0.275034     2.54     3.15
# stroke            211.0      3.246540     0.319686     2.07     3.11
# compressionratio  211.0     10.110047     3.919511     7.00     8.60
# horsepower        211.0    104.720379    39.284827    48.00    70.00
# peakrpm           211.0   5121.563981   470.584155  4150.00  4800.00
# ...

# %%
df[col_object].describe().T
# Out:
#                count unique          top freq
# CarName          211    147  peugeot 504    6
# fueltype         211      2          gas  191
# aspiration       211      2          std  174
# doornumber       211      2         four  115
# carbody          211      5        sedan   96
# drivewheel       211      3          fwd  120
# enginelocation   211      2        front  208
# enginetype       211      7          ohc  148
# cylindernumber   211      7         four  163
# fuelsystem       211      8         mpfi  100

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       1          3        alfa-romero giulia      gas        std        two
# 4       2          3       alfa-romero stelvio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
# 3  convertible        rwd          front       88.6  ...        mpfi
# 4  convertible        rwd          front       88.6  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# ...

# %%
df["fueltype"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df["fueltype"].value_counts()
# Out:
# gas       191
# diesel     20
# Name: fueltype, dtype: int64

# %%
df["carbody"].value_counts()
# Out:
# sedan          96
# hatchback      72
# wagon          25
# convertible    10
# hardtop         8
# Name: carbody, dtype: int64

# %%
df.query("fueltype == 'gas' ")["price"].max()
# Out:
# 45400.0

# %%
df.query("fueltype == 'diesel' ")["price"].max()
# Out:
# 31600.0

# %%
df.groupby("fueltype")["price"].max()
# Out:
# fueltype
# diesel    31600.0
# gas       45400.0
# Name: price, dtype: float64

# %%
df.groupby("carbody")["price"].agg(["min" , "max" , "mean" , "count"])
# Out:
#                  min      max          mean  count
# carbody
# convertible  11595.0  37028.0  19133.300000     10
# hardtop       8249.0  45400.0  22208.500000      8
# hatchback     5118.0  31400.5  10546.745375     72
# sedan         5499.0  41315.0  14344.270833     96
# wagon         6918.0  28248.0  12371.960000     25

# %%
df["drivewheel"].value_counts()
# Out:
# fwd    120
# rwd     82
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
df.groupby(["enginelocation" , "carbody" , "fueltype"] )["price"].agg(["min" , "max" , "mean" , "count"])
# Out:
#                                          min      max          mean  count
# enginelocation carbody     fueltype
# front          convertible gas       11595.0  35056.0  17145.000000      9
#                hardtop     diesel    28176.0  28176.0  28176.000000      1
#                            gas        8249.0  45400.0  16587.200000      5
#                hatchback   diesel     7788.0   7788.0   7788.000000      1
#                            gas        5118.0  31400.5  10585.600944     71
#                sedan       diesel     7099.0  31600.0  14774.400000     15
#                            gas        5499.0  41315.0  14264.617284     81
#                wagon       diesel    13860.0  28248.0  19727.666667      3
#                            gas        6918.0  18950.0  11368.909091     22
# rear           convertible gas       37028.0  37028.0  37028.000000      1
#                hardtop     gas       32528.0  34028.0  33278.000000      2

# %%
# "horsepower"
# "cylindernumber"

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
df.groupby("cylindernumber")["price"].agg(["min" , "max" , "mean" , "count"]).sort_values(by="count").reset_index()
# Out:
#   cylindernumber      min      max          mean  count
# 0          three   5151.0   5151.0   5151.000000      1
# 1         twelve  36000.0  36000.0  36000.000000      1
# 2            two  10945.0  15645.0  13020.000000      4
# 3          eight  31400.5  45400.0  37400.100000      5
# 4           five  13295.0  31600.0  21630.469727     11
# 5            six  13499.0  41315.0  23120.153846     26
# 6           four   5118.0  22625.0  10401.380368    163

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       1          3        alfa-romero giulia      gas        std        two
# 4       2          3       alfa-romero stelvio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
# 3  convertible        rwd          front       88.6  ...        mpfi
# 4  convertible        rwd          front       88.6  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# ...

# %%
try:
    df.drop("car_ID" , axis= 1 , inplace= True)     # axis= 1 >>> col   axis= 0 >>> row
except Exception as e :
    print("Error:", e )
# Out:
# Error: "['car_ID'] not found in axis"

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            3        alfa-romero giulia      gas        std        two
# 4            3       alfa-romero stelvio      gas        std        two
# ..         ...                       ...      ...        ...        ...
# 206         -1           volvo 145e (sw)      gas        std       four
# 207         -1               volvo 144ea      gas      turbo       four
# 208         -1               volvo 244dl      gas        std       four
# 209         -1                 volvo 246   diesel      turbo       four
# 210         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
# df = df.drop("symboling" , axis=1 )
try:
    df.drop("symboling" , axis = 1 , inplace=True)
except Exception as e :
    print("Error:" , e)
# Out:
# Error: "['symboling'] not found in axis"

# %%
df
# Out:
#                       CarName fueltype aspiration doornumber      carbody  \
# 0          alfa-romero giulia      gas        std        two  convertible
# 1         alfa-romero stelvio      gas        std        two  convertible
# 2    alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3          alfa-romero giulia      gas        std        two  convertible
# 4         alfa-romero stelvio      gas        std        two  convertible
# ..                        ...      ...        ...        ...          ...
# 206           volvo 145e (sw)      gas        std       four        sedan
# 207               volvo 144ea      gas      turbo       four        sedan
# 208               volvo 244dl      gas        std       four        sedan
# 209                 volvo 246   diesel      turbo       four        sedan
# 210               volvo 264gl      gas      turbo       four        sedan
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  ...  \
# ...

# %%
df["CarName"].value_counts()
# Out:
# peugeot 504         6
# toyota corolla      6
# toyota corona       6
# subaru dl           4
# mazda 626           3
#                    ..
# mazda glc 4         1
# mazda rx2 coupe     1
# maxda glc deluxe    1
# maxda rx3           1
# volvo 246           1
# Name: CarName, Length: 147, dtype: int64

# %%
df["CarName"].nunique()
# Out:
# 147

# %%
# x = "amit learning"
# x.split()[0]

# %%
df["CarName"] = df["CarName"].str.split(expand= True)[0]

# %%
df["CarName"]
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3      alfa-romero
# 4      alfa-romero
#           ...
# 206          volvo
# 207          volvo
# 208          volvo
# 209          volvo
# 210          volvo
# Name: CarName, Length: 211, dtype: object

# %%
df["CarName"].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# alfa-romero     9
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: CarName, dtype: int64

# %%
df[["CarName"]].describe()
# Out:
#        CarName
# count      211
# unique      28
# top     toyota
# freq        31

# %%
# x = "amit learning"
# print(x.title())
# print(x.capitalize())

# %%
df["CarName"] = df["CarName"].str.title()        
# df["CarName"] = df["CarName"].apply(str.title)    # map(fun , seq)

# %%
df["CarName"].value_counts()
# Out:
# Toyota         31
# Nissan         18
# Mazda          15
# Honda          13
# Mitsubishi     13
# Subaru         12
# Peugeot        11
# Volvo          11
# Alfa-Romero     9
# Dodge           9
# Volkswagen      9
# Bmw             8
# Buick           8
# Audi            7
# Plymouth        7
# Saab            6
# Isuzu           4
# Porsche         4
# Jaguar          3
# Chevrolet       3
# Vw              2
# Maxda           2
# Renault         2
# Toyouta         1
# Vokswagen       1
# Mercury         1
# Porcshce        1
# Name: CarName, dtype: int64

# %%
# df["CarName"].apply(len)

# %%
df["CarName"] = df["CarName"].replace({"Maxda": "Mazda" , "Toyouta" : "Toyota"})

# %%
df["CarName"].value_counts()
# Out:
# Toyota         32
# Nissan         18
# Mazda          17
# Honda          13
# Mitsubishi     13
# Subaru         12
# Peugeot        11
# Volvo          11
# Alfa-Romero     9
# Volkswagen      9
# Dodge           9
# Buick           8
# Bmw             8
# Audi            7
# Plymouth        7
# Saab            6
# Isuzu           4
# Porsche         4
# Chevrolet       3
# Jaguar          3
# Renault         2
# Vw              2
# Vokswagen       1
# Mercury         1
# Porcshce        1
# Name: CarName, dtype: int64

# %%
df["CarName"].nunique()
# Out:
# 25

# %%
# str.split(expand= True)[0]
# str.title
# df["CarName"].replace({"Maxda": "Mazda" , "Toyouta" : "Toyota"})
# groupby(CarName)

# %%
# df["carname"] = df["CarName"].replace({"Maxda": "Mazda" , "Toyouta" : "Toyota"})

# %%
# pd.DataFrame(x)

# %%
# df

# %%
df.head()
# Out:
#        CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0  Alfa-Romero      gas        std        two  convertible        rwd
# 1  Alfa-Romero      gas        std        two  convertible        rwd
# 2  Alfa-Romero      gas        std        two    hatchback        rwd
# 3  Alfa-Romero      gas        std        two  convertible        rwd
# 4  Alfa-Romero      gas        std        two  convertible        rwd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  boreratio  stroke  \
# 0          front       88.6      168.8      64.1  ...       3.47    2.68
# 1          front       88.6      168.8      64.1  ...       3.47    2.68
# 2          front       94.5      171.2      65.5  ...       2.68    3.47
# 3          front       88.6      168.8      64.1  ...       3.47    2.68
# 4          front       88.6      168.8      64.1  ...       3.47    2.68
#
#   compressionratio horsepower  peakrpm citympg  highwaympg    price  \
# ...

# %%
df["price"].describe()
# Out:
# count      211.000000
# mean     13339.884678
# std       7886.229997
# min       5118.000000
# 25%       7847.000000
# 50%      10698.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
q1 = df["price"].quantile(.25)

# %%
q3 = df["price"].quantile(.75)

# %%
IQR = q3 - q1 
IQR
# Out:
# 8653.0

# %%
lower = q1 - (1.5 * IQR)
lower = 0

# %%
upper = q3 + (1.5 * IQR)
upper
# Out:
# 29479.5

# %%
df_without_outlires = df[df["price"] <= upper]

# %%
df_without_outlires["price"].max()
# Out:
# 28248.0

# %%
df["price"].max()
# Out:
# 45400.0

# %%
df_without_outlires["price"].mean()
# Out:
# 11631.511056122448

# %%
df["price"].mean()
# Out:
# 13339.884677725118

# %%
df2 = pd.read_csv(r"C:\Users\AMIT\Documents\2 Data Science Preparation 30h\data science pre\DS G 51\AB_NYC_2019.csv")

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df["last_review"] = pd.to_datetime(df["last_review"])

# %%
df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                    float64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %%
df["day"]   =  df["last_review"].dt.day
df["month"] = df["last_review"].dt.month
df["year"]  = df["last_review"].dt.year

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px 
# !pip install plotly
# !pip install seaborn

# %%
df.shape
# Out:
# (48895, 19)

# %%
48891
